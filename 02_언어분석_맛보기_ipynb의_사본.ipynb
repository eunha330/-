# %% [markdown]
# <a href="https://colab.research.google.com/github/eunha330/eunha/blob/main/02_%EC%96%B8%EC%96%B4%EB%B6%84%EC%84%9D_%EB%A7%9B%EB%B3%B4%EA%B8%B0_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title N-Gram - 띄어쓰기 기준 분리
문장 = '\uC2A4\uD1A0\uB9AC \uC5C6\uB2E4\uACE0 \uD558\uB294\uBD84\uB4E4 \uC2E0\uAE30   \uC6B8\uACE0\uC2F6\uC740\uBD84\uB4E4  \uAF2D \uBCF4\uC138\uC694   \uD734\uC9C0\uD544\uC218 \uC2AC\uD508 \uC601\uD654\uB77C \uC0DD\uAC01\uD569\uB2C8\uB2E4. \uB208\uBB3C \uC904\uC904 \uC3DF\uC73C\uBA70 \uBD24\uC5B4\uC694.\uB2E4\uB9CC \uAC10\uB3D9\uC801\uC774\uC9C0\uB294 \uC54A\uC2B5\uB2C8\uB2E4. \uC601\uD654 \uC18D \uC778\uBB3C\uC5D0\uAC8C \uAC10\uC815\uC774\uC785\uD574\uC11C \uBCFC \uC218 \uC788\uB2E4\uBA74 \uD6CC\uB96D\uD55C \uD0AC\uB9C1\uD0C0\uC784\uC6A9 \uC601\uD654\uC77C\uAC70\uB77C \uC0DD\uAC01\uD569\uB2C8\uB2E4\uB9CC \uC911\uAC04\uC911\uAC04 \uC624\uBC84\uC2A4\uB7EC\uC6B4 \uC7A5\uBA74\uB4E4\uACFC \uC2A4\uD1A0\uB9AC\uAC00 \uC774\uC785\uC744 \uBC29\uD574\uD558... \uC2AC\uD504\uACE0 \uAC10\uB3D9\uC801\uC778\uAC78 \uC88B\uC544\uD574\uC11C \uD560\uBA38\uB2C8\uC640 \uC190\uB140 \uC8FC\uC81C\uB780 \uAC83\uB9CC\uC73C\uB85C\uB3C4 \uAE30\uB300\uB97C \uD558\uACE0 \uBD24\uC73C\uB098,,, \uC194\uC9C1\uD788 \uAE30\uB300\uB97C \uB5A0\uB098 \uAE30\uB300\uBCF4\uB2E4 \uBABB\uD55C\uAC74 \uB2F9\uC5F0\uD558\uC9C0\uB9CC \uBCC4\uB85C\uC600\uC2B5\uB2C8\uB2E4,, \uADF8\uB0E5 \uB4DC\uB77C\uB9C8 \uC218\uC900 \uC774\uB124\uC694,, \uD06C\uAC8C \uB208\uBB3C \uD758\uB9B4\uB9CC\uD55C \uD3EC\uC778\uD2B8\uB3C4 \uBCC4\uB85C \uC5C6\uC5C8\uC5B4... \uC774\uAC70 \uBCF4\uACE0 \uC548 \uC6B8\uBA74 10\uB9CC\uC6D0 \uB4DC\uB824\uC694 \u314E\u314E \uC544\uB2C8 \uB313\uAE00\uB4E4 \uBB50\uC57C \uC601\uD654 \uC0AC\uD22C\uB9AC\uB85C \uBCF4\uB0D0?\uC5F0\uAE30 \uBABB\uD574\uB3C4 \uB9D0 \uC798\uD558\uBA74 \uB418\uB294\uAC74\uAC00,,,\uC548\uC2AC\uD508\uB2E4\uACE0 \uD558\uB294\uAC83\uB4E4 \uC0AC\uB78C\uC774\uB0D0 \uB2E4\uB978\uAC83\uB3C4 \uC544\uB2C8\uACE0\uAC00
A8\uB294 \uC601\uD654\uC774\uB2E4. \uC5C4\uCCAD \uC6B8\uC5C8\uC5B4\uC694 \u315C\u315C \uC81C \uC778\uC0DD \uC601\uD654 \uC785\uB2C8\uB2E4 \uC5B4\uB5BB\uAC8C \uC774\uAC8C 1\uC810\uB300 \uD3C9\uC810\uC774 \uB098\uC624\uC8E0..?\uB098\uC9C4\uC9DC \uC7AC\uBC0C\uAC8C \uBCF4\uACE0 \uC77C\uB2E8 \uD734\uC9C0\uD544\uC218 \uB208\uBB3C\uCF67\uBB3C\uB108\uBB34\uB098\uC11C \uBBFC\uB9DD\uD588\uB294\uB370;;;\uB098\uBB38\uD76C\uB2D8..\uC560\uAE30\uBC30\uC6B0\uB3C4 \uB0B4\uB208\uBB3C\uC9C0\uB8B0\uB4E4... \uB098\uBB38\uD76C\uB791 \uC544\uC5ED\uC774  \uC5F4\uC5F0 \uC5F0\uAE30\uD3BC\uCCD0\uB193\uC73C\uB2C8   \uD6C4\uBC18\uC5D0\uB098\uC640\uC11C  \uAC1C\uD3FC\uB9CC \uC7A1\uB124  \uC5B4\uB978\uB41C\uBAA8\uC2B5\uC774 \uC218\uC601 \uC778\uAC70\uBCF4\uACE0  \uAC1C\uC2E4\uB9DD\uD568 \uB300\uC77C\uBCF8\uC81C\uAD6D\uC758 \uC6B0\uC218\uD55C \uC120\uC9C4\uBB38\uD654\uB97C \uBC30\uC6CC\uC624\uC138\uC694.. \uC774 \uC870\uC13C\uC9D5\uB4E4\uC544~~~ \u315C\u315C\u315C \uC644\uC804 \uAC10\uB3D9 \uD3ED\uBC1C \uAC10\uB3D9\uC2A4\uB7FD\uACE0\uC7AC\uBC0C\uACE0 \uADF8\uB7F0\uC601\uD654\uC608\uC694\uB9C8\uC74C\uB530\uB73B\uD574\uC9C0\uB294\uC601\uD654\uB77C\uC11C \uB3C8\uC544\uAE5D\uC9C0\uC54A\uC558\uC5B4\uC694~^^ \uAC10\uB3D9\uB3C4 \uC7AC\uBBF8\uB3C4 \uC544\uBB34\uAC83\uB3C4 \uC5C6\uB2E4'  #@param {type: "string"}
NGram크기 = "5" #@param ["1", "2", "3", "4", "5", "6"] {allow-input: true}

from nltk import ngrams

ngrams = ngrams(문장.split(), int(NGram크기))

for grams in ngrams:
  print(grams)
# Out:
# ('스토리', '없다고', '하는분들', '신기', '울고싶은분들')
# ('없다고', '하는분들', '신기', '울고싶은분들', '꼭')
# ('하는분들', '신기', '울고싶은분들', '꼭', '보세요')
# ('신기', '울고싶은분들', '꼭', '보세요', '휴지필수')
# ('울고싶은분들', '꼭', '보세요', '휴지필수', '슬픈')
# ('꼭', '보세요', '휴지필수', '슬픈', '영화라')
# ('보세요', '휴지필수', '슬픈', '영화라', '생각합니다.')
# ('휴지필수', '슬픈', '영화라', '생각합니다.', '눈물')
# ('슬픈', '영화라', '생각합니다.', '눈물', '줄줄')
# ('영화라', '생각합니다.', '눈물', '줄줄', '쏟으며')
# ('생각합니다.', '눈물', '줄줄', '쏟으며', '봤어요.다만')
# ('눈물', '줄줄', '쏟으며', '봤어요.다만', '감동적이지는')
# ('줄줄', '쏟으며', '봤어요.다만', '감동적이지는', '않습니다.')
# ('쏟으며', '봤어요.다만', '감동적이지는', '않습니다.', '영화')
# ('봤어요.다만', '감동적이지는', '않습니다.', '영화', '속')
# ('감동적이지는', '않습니다.', '영화', '속', '인물에게')
# ('않습니다.', '영화', '속', '인물에게', '감정이입해서')
# ('영화', '속', '인물에게', '감정이입해서', '볼')
# ('속', '인물에게', '감정이입해서', '볼', '수')
# ('인물에게', '감정이입해서', '볼', '수', '있다면')
# ('감정이입해서', '볼', '수', '있다면', '훌륭한')
# ('볼', '수', '있다면', '훌륭한', '킬링타임용')
# ('수', '있다면', '훌륭한', '킬링타임용', '영화일거라')
# ('있다면', '훌륭한', '킬링타임용', '영화일거라', '생각합니다만')
# ...

# %%
#@title N-Gram - 1글자 기준 분리
문장 = '\u6211\u7231\u4F60\u3002\u5982\u679C\u8981\u5728\u4E2A\u5206\u611F\u60C5\u4E0A\u52A0\u4E0A\u4E00\u4E2A\u671F\u9650\u7684\u8BDD\u6211\u5E0C\u671B\u662F\u6709\u4E07\u5E74\uFF01'  #@param {type: "string"}
NGram크기 = "3" #@param ["1", "2", "3", "4", "5", "6"] {allow-input: true}

from nltk import ngrams

ngrams = list(ngrams(문장, int(NGram크기)))

for grams in ngrams:
  print(grams)
# Out:
# ('我', '爱', '你')
# ('爱', '你', '。')
# ('你', '。', '如')
# ('。', '如', '果')
# ('如', '果', '要')
# ('果', '要', '在')
# ('要', '在', '个')
# ('在', '个', '分')
# ('个', '分', '感')
# ('分', '感', '情')
# ('感', '情', '上')
# ('情', '上', '加')
# ('上', '加', '上')
# ('加', '上', '一')
# ('上', '一', '个')
# ('一', '个', '期')
# ('个', '期', '限')
# ('期', '限', '的')
# ('限', '的', '话')
# ('的', '话', '我')
# ('话', '我', '希')
# ('我', '希', '望')
# ('希', '望', '是')
# ('望', '是', '有')
# ('是', '有', '万')
# ('有', '万', '年')
# ('万', '年', '！')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title 한국어 형태소 분석 - konlpy(kkma)
한국어문장 = '\uC2A4\uD1A0\uB9AC \uC5C6\uB2E4\uACE0 \uD558\uB294\uBD84\uB4E4 \uC2E0\uAE30   \uC6B8\uACE0\uC2F6\uC740\uBD84\uB4E4  \uAF2D \uBCF4\uC138\uC694   \uD734\uC9C0\uD544\uC218 \uC2AC\uD508 \uC601\uD654\uB77C \uC0DD\uAC01\uD569\uB2C8\uB2E4. \uB208\uBB3C \uC904\uC904 \uC3DF\uC73C\uBA70 \uBD24\uC5B4\uC694.\uB2E4\uB9CC \uAC10\uB3D9\uC801\uC774\uC9C0\uB294 \uC54A\uC2B5\uB2C8\uB2E4. \uC601\uD654 \uC18D \uC778\uBB3C\uC5D0\uAC8C \uAC10\uC815\uC774\uC785\uD574\uC11C \uBCFC \uC218 \uC788\uB2E4\uBA74 \uD6CC\uB96D\uD55C \uD0AC\uB9C1\uD0C0\uC784\uC6A9 \uC601\uD654\uC77C\uAC70\uB77C \uC0DD\uAC01\uD569\uB2C8\uB2E4\uB9CC \uC911\
\uB300\uC77C\uBCF8\uC81C\uAD6D\uC758 \uC6B0\uC218\uD55C \uC120\uC9C4\uBB38\uD654\uB97C \uBC30\uC6CC\uC624\uC138\uC694.. \uC774 \uC870\uC13C\uC9D5\uB4E4\uC544~~~ \u315C\u315C\u315C \uC644\uC804 \uAC10\uB3D9 \uD3ED\uBC1C \uAC10\uB3D9\uC2A4\uB7FD\uACE0\uC7AC\uBC0C\uACE0 \uADF8\uB7F0\uC601\uD654\uC608\uC694\uB9C8\uC74C\uB530\uB73B\uD574\uC9C0\uB294\uC601\uD654\uB77C\uC11C \uB3C8\uC544\uAE5D\uC9C0\uC54A\uC558\uC5B4\uC694~^^ \uAC10\uB3D9\uB3C4 \uC7AC\uBBF8\uB3C4 \uC544\uBB34\uAC83\uB3C4 \uC5C6\uB2E4'  #@param {type: "string"}


# konlpy 설치하기 ## https://data1000.tistory.com/33
# !pip3 install jpype1==0.7.0
# !pip3 install konlpy

from IPython.display import clear_output
clear_output()

from konlpy.tag import Kkma
from konlpy.utils import pprint
kkma = Kkma()

print("  ")
print("###문장 분리###")
print(kkma.sentences(한국어문장))

print("  ")
print("###명사 추출###")
print(kkma.nouns(한국어문장))

print("  ")
print("###형태소 분리###")
print(kkma.morphs(한국어문장))

print("  ")
print("###품사 태깅###")
print(kkma.pos(한국어문장))
# Out:
#
# ###문장 분리###
# ...

# %%
#@title 한국어 형태소 분석 - konlpy(okt)
한국어문장 = '\uC2A4\uD1A0\uB9AC \uC5C6\uB2E4\uACE0 \uD558\uB294\uBD84\uB4E4 \uC2E0\uAE30   \uC6B8\uACE0\uC2F6\uC740\uBD84\uB4E4  \uAF2D \uBCF4\uC138\uC694   \uD734\uC9C0\uD544\uC218 \uC2AC\uD508 \uC601\uD654\uB77C \uC0DD\uAC01\uD569\uB2C8\uB2E4. \uB208\uBB3C \uC904\uC904 \uC3DF\uC73C\uBA70 \uBD24\uC5B4\uC694.\uB2E4\uB9CC \uAC10\uB3D9\uC801\uC774\uC9C0\uB294 \uC54A\uC2B5\uB2C8\uB2E4. \uC601\uD654 \uC18D \uC778\uBB3C\uC5D0\uAC8C \uAC10\uC815\uC774\uC785\uD574\uC11C \uBCFC \uC218 \uC788\uB2E4\uBA74 \uD6CC\uB96D\uD55C \uD0AC\uB9C1\uD0C0\uC784\uC6A9 \uC601\uD654\uC77C\uAC70\uB77C \uC0DD\uAC01\uD569\uB2C8\uB2E4\uB9CC \uC911\uAC04\uC911\uAC04 \uC624\uBC84\uC2A4\uB7EC\uC6B4 \uC7A5\uBA74\uB4E4\uACFC \uC2A4\uD1A0\uB9AC\uAC00 \uC774\uC785\uC744 \uBC29\uD574\uD558... \uC2AC\uD504\uACE0 \uAC10\uB3D9\uC801\uC778\uAC78 \uC88B\uC544\uD574\uC11C \uD560\uBA38\uB2C8\uC640 \uC190\uB140 \uC8FC\uC81C\uB780 \uAC83\uB9CC\uC73C\uB85C\uB3C4 \uAE30\uB300\uB97C \uD558\uACE0 \uBD24\uC73C\uB098,,, \uC194\uC9C1\uD788 \uAE30\uB300\uB97C \uB5A0\uB098 \uAE30\uB300\uBCF4\uB2E4 \uBABB\uD55C\uAC74 \uB2F9\uC5F0\uD558\uC9C0\uB9CC \uBCC4\uB85C\uC600\uC2B5\uB2C8\uB2E4,, \uADF8\uB0E5 \uB4DC\uB77C\uB9C8 \uC218\uC900 \uC774\uB124\uC694,, \uD06C\uAC8C \uB208\uBB3C \uD758\uB9B4\uB9CC\uD55C \uD3EC\uC778\uD2B8\uB3C4 \uBCC4\uB85C \uC5C6\uC5C8\uC5B4... \uC774\uAC70 \uBCF4\uACE0 \uC548 \uC6B8\uBA74 10\uB9CC\uC6D0 \uB4DC\uB824\uC694 \u314E\u314E \uC544\uB2C8 \uB313\uAE00\uB4E4 \uBB50\uC57C \uC601\uD654 \uC0AC\uD22C\uB9AC\uB85C \uBCF4\uB0D0?\uC5F0\uAE30 \uBABB\uD574\uB3C4 \uB9D0 \uC798\uD558\uBA74 \uB418\uB294\uAC74\uAC00,,,\uC548\uC2AC\uD508\uB2E4\uACE0 \uD558\uB294\uAC83\uB4E4 \uC0AC\uB78C\uC774\uB0D0 \uB2E4\uB978\uAC83\uB3C4 \uC544\uB2C8\uACE0\uAC00\uC871\uC744 \uB2E4\uB8E8\uB294 \uC774\uC57C\uAE30\uC778\uB370 \u314E  \uC794\uC794\uD55C\uAC10\uB3D9\uC73C\uB85C \uC7AC\uBC0C\uAC8C\uBD24\uC2B5\uB2C8\uB2E4 \uC5EC\uC790\uD2F4\uAD6C\uB791 \uB208\uBB3C\uCF67\uBB3C \uB2E4\uBE8C... \uBCF4\uB294 \uB0B4\uB0B4 \uD560\uBA38\uB2C8 \uC0DD\uAC01\uB098\uC11C \uB208\uBB3C\uC774 \uBA48\uCD94\uC9C8\uC54A\uC558\uC2B5\uB2C8\uB2F9...\u3160\u3160 \uB3CC\uC544\uAC00\uC2E0 \uD560\uBA38\uB2C8 \uBCF4\uACE0\uC2F6\uC5C8\uC5B4\uC694 \uC9C4\uC9DC \uBCF4\uACE0 \uC6B8\uC5B4\uBC84\uB9B0 \uC601\uD654\uB294 \uCC98\uC74C\uC774\uB2E4.\uC9C4\uC9DC \uBE44\uB9B0\uB0B4\uB0A0\uC815\uB3C4\uB85C \uC6B8\uC5C8\uB2E4.\uC637\uC774 \uB2E4\uC816\uC74C \uD558 \uCC3D\uD53C\uD574 \uB208\uBB3C \uCF67\uBB3C \uC3D9 \uD391\uD391 \u3160\u3160 \uC664\uCF00 \uAC10\uB3D9\uC801\uC778\uAC70\uC57C \uD558\uC774\uACE0.... \uC911\uB529 1\uD559\uB144 \uB0B4 \uB538\uC774 \uAC10\uB3D9 \uBC1B\uC544\uC11C \uC544\uBE60, \uC5C4\uB9C8\uB791 \uB2E4\uC2DC \uBD10\uC57C \uD55C\uB2E4\uACE0 \uD574\uC11C \uC5B4\uB835\uAC8C \uC2DC\uAC04 \uB0B4\uC11C \uBD24\uB354\uB2C8... \uD558\uC774\uACE0....\uADF8\uB0E5 \uC5B4\uB978\uB4E4\uC758 \uC801\uB2F9\uD55C \uAD00\uB78C\uC728 \uB192\uC774\uB294 \uC544\uC8FC \uC804\uD615\uC801\uC778, \uC815\uB9D0  \uC2DD\uC0C1\uD55C \uACF5\uC2DD\uC774\uC5C8\uAD70\uC694.\uB538\uC774 \uC65C...  \uB098\uB984 \uBCFC\uB9CC\uD588\uB294\uB370 \uD3C9\uC810\uC774 \uC548\uC88B\uB124;;; \uB3CC\uC544\uAC00\uC2E0 \uD560\uBA38\uB2C8 \uC0DD\uAC01\uB098\uB354\uAD6C\uBA3C  \uC624\uB7AB\uB9CC\uC5D0 \uC601\uD654\uB2E4\uC6B4 \uC601\uD654\uB97C \uBD24\uC2B5\uB2C8\uB2E4. \uC5ED\uC2DC \uB098\uBB38\uD76C!\uBBFF\uACE0 \uBCF4\uBA70 \uD6C4\uD68C\uD558\uC9C0 \uC54A\uB294 \uC601\uD654.\uC190\uC218\uAC74 \uC900\uBE44\uD558\uC2DC\uAE38...\uC601\uD654\uAC00 \uB05D\uB098\uACE0, \uACE0\uD5A5\uC9D1\uC5D0 \uC804\uD654\uD558\uC2DC\uB9AC \uC0AC\uD22C\uB9AC \uC548\uB418\uB294 \uBC30\uC6B0 \uC880 \uC4F0\uC9C0\uB9C8\uB77C..\uB300\uD55C\uBBFC\uAD6D \uC5B4\uB51C\uAC00\uB3C4 \uC800\uB7F0 \uC0AC\uD22C\uB9AC \uC5B5\uC591\uC5C6\uB2E4..5\uBD84 \uBCF4\uB2E4\uAC00 \uC9DC\uC99D\uB098\uC11C \uAED0\uB2E4  \uC5F0\uAE30\uB3C4 \uB108\uBB34 \uC798\uD558\uACE0 \u3160\u3160 \uC0DD\uAC01\uC5C6\uC774 \uBD24\uB294\uB370 \uB108\uBB34 \uC88B\uC557\uC5B4\uC694 \u3160\u3160 \uAC10\uCABD\uAC19\uC740 \uC601\uD654\uC600\uC5B4\uC694 \uC815\uB9D0 \u315C\u315C \uBCF4\uBA74\uC11C \uC678\uD560\uBA38\uB2C8 \uC0DD\uAC01\uC774 \uB9CE\uC774 \uB098\uC11C \uBAB0\uC785\uD558\uBA70 \uBCF4\uB294 \uB0B4\uB0B4 \uC6B8\uC74C\uC774 \uC548 \uADF8\uCCE4\uC5B4\uC694 \uC815\uB9D0 \uAC10\uB3D9\uC774\uACE0 \uC2AC\uD504\uACE0 \uC774\uB7F0 \uC601\uD654\uB97C \uB9CC\uB4E4\uC5B4 \uC8FC\uC154\uC11C \uAC10\uC0AC\uD569\uB2C8\uB2E4...  \uC815\uB9D0 \uAC15\uB825 \uCD94\uCC9C\uD569\uB2C8\uB2E4 \uCC98\uC74C\uC73C\uB85C \uD391\uD391 \uC6B8\uBA74\uC11C \uBCF4\uACE0  \uB098\uC628 \uC601\uD654..\uC5F0\uAE30\uB825.. \uC2A4\uD1A0\uB9AC.. \uBAA8\uB450..\uCD5C\uACE0 \uC600\uC5B4\uC694.. \uC6B8\uC5C8\uC74C..\uB208\uBB3C\uC774 \uC8FC\uB975\uC8FC\uB975..\uAC00\uC871\uC601\uD654\uB85C \uC88B\uC74C.. \uCC38 \uC7AC\uBC0C\uAC8C \uBD24\uC74C..\uC774\uC601\uD654~ \uB9E4\uB825\uC788\uB124~ \uC624\uB79C\uB9CC\uC5D0 \uD391\uD391\uC6B8\uC5C8\uB124\uC694 \uC9C4\uC9DC \uAC00\uC2B4\uC744\uC6B8\uB9AC\uB294 \uC5F0\uAE30\uC778\uAC70\uAC19\uC2B5\uB2C8\uB2E4.\uC2A4\uD1A0\uB9AC\uB3C4 \uC815\uB9D0 \uD604\uC2E4\uAC10\uC788\uC5C8\uC2B5\uB2C8\uB2E4 \uD2B9\uD788 \uB098\uBB38\uD76C \uB300\uBC30\uC6B0\uB2D8\uACFC \uC774\uC218\uC548 \uBC30\uC6B0\uC758 \uCE90\uBBF8\uB825\uC744 \uBCFC\uC218\uC788\uC5B4\uC11C \uB118 \uC88B\uC558\uC2B5\uB2C8\uB2E4. \uC548\uC6B8\uB798\uC57C \uC548\uC6B8\uC218\uAC00 \uC5C6\uB294 \uC601\uD654... 7\uBC88\uBC29 \uBCF4\uACE0\uB3C4 \uC548\uC6B8\uACE0 \uC660\uB9CC\uD574\uC11C\uB294 \uC548\uC6B0\uB294\uB370 \uB108\uBB34 \uC2AC\uD504\uB2E4 \uB098\uBB38\uD76C \uD560\uBA38\uB2C8 \uC5F0\uAE30\uAC00 \uB108\uBB34 \uAC00\uC2B4\uC744 \uC6B8\uB9B0\uB2E4. \uC9D1\uAC00\uC11C \uB610 \uC6B8 \uAC83 \uAC19\uC740... \uB9CE\uC774 \uC5EC\uC6B4\uC774 \uB0A8\uB294 \uC601\uD654\uC774\uB2E4. \uC5C4\uCCAD \uC6B8\uC5C8\uC5B4\uC694 \u315C\u315C \uC81C \uC778\uC0DD \uC601\uD654 \uC785\uB2C8\uB2E4 \uC5B4\uB5BB\uAC8C \uC774\uAC8C 1\uC810\uB300 \uD3C9\uC810\uC774 \uB098\uC624\uC8E0..?\uB098\uC9C4\uC9DC \uC7AC\uBC0C\uAC8C \uBCF4\uACE0 \uC77C\uB2E8 \uD734\uC9C0\uD544\uC218 \uB208\uBB3C\uCF67\uBB3C\uB108\uBB34\uB098\uC11C \uBBFC\uB9DD\uD588\uB294\uB370;;;\uB098\uBB38\uD76C\uB2D8..\uC560\uAE30\uBC30\uC6B0\uB3C4 \uB0B4\uB208\uBB3C\uC9C0\uB8B0\uB4E4... \uB098\uBB38\uD76C\uB791 \uC544\uC5ED\uC774  \uC5F4\uC5F0 \uC5F0\uAE30\uD3BC\uCCD0\uB193\uC73C\uB2C8   \uD6C4\uBC18\uC5D0\uB098\uC640\uC11C  \uAC1C\uD3FC\uB9CC \uC7A1\uB124  \uC5B4\uB978\uB41C\uBAA8\uC2B5\uC774 \uC218\uC601 \uC778\uAC70\uBCF4\uACE0  \uAC1C\uC2E4\uB9DD\uD568 \uB300\uC77C\uBCF8\uC81C\uAD6D\uC758 \uC6B0\uC218\uD55C \uC120\uC9C4\uBB38\uD654\uB97C \uBC30\uC6CC\uC624\uC138\uC694.. \uC774 \uC870\uC13C\uC9D5\uB4E4\uC544~~~ \u315C\u315C\u315C \uC644\uC804 \uAC10\uB3D9 \uD3ED\uBC1C \uAC10\uB3D9\uC2A4\uB7FD\uACE0\uC7AC\uBC0C\uACE0 \uADF8\uB7F0\uC601\uD654\uC608\uC694\uB9C8\uC74C\uB530\uB73B\uD574\uC9C0\uB294\uC601\uD654\uB77C\uC11C \uB3C8\uC544\uAE5D\uC9C0\uC54A\uC558\uC5B4\uC694~^^ \uAC10\uB3D9\uB3C4 \uC7AC\uBBF8\uB3C4 \uC544\uBB34\uAC83\uB3C4 \uC5C6\uB2E4'  #@param {type: "string"}


# konlpy 설치하기 ## https://data1000.tistory.com/33
# !pip3 install jpype1==0.7.0
# !pip3 install konlpy

from IPython.display import clear_output
clear_output()

from konlpy.tag import Okt
from konlpy.utils import pprint
okt = Okt()

print("  ")
print("###명사 추출###")
print(okt.nouns(한국어문장))

print("  ")
print("###형태소 분리###")
print(okt.morphs(한국어문장))

print("  ")
print("###품사 태깅###")
print(okt.pos(한국어문장))
# Out:
#
# ###명사 추출###
# ...

# %%
#@title 중국어 형태소 분석 - Jieba
중국어문장 = '\u6211\u7231\u4F60\u3002\u5982\u679C\u8981\u5728\u4E2A\u5206\u611F\u60C5\u4E0A\u52A0\u4E0A\u4E00\u4E2A\u671F\u9650\u7684\u8BDD\u6211\u5E0C\u671B\u662F\u6709\u4E07\u5E74\uFF01'  #@param {type: "string"}

# !pip install jieba
from IPython.display import clear_output
clear_output()
# encoding=utf-8

import jieba

seg_list = jieba.cut(중국어문장)  # 默认是精确模式
print("  ")
print("###精确模式###")
print(", ".join(seg_list))

seg_list = jieba.cut_for_search(중국어문장)  # 搜索引擎模式
print("  ")
print("###搜索引擎模式###")
print(", ".join(seg_list))

import jieba.posseg as pseg
words = pseg.cut(중국어문장)
print("  ")
print("###词性标注###")
for word, flag in words:
  print('%s %s' % (word, flag))
# Out:
# Building prefix dict from the default dictionary ...
#
# ###精确模式###
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.955 seconds.
# Prefix dict has been built successfully.
# 我爱你, 。, 如果, 要, 在, 个, 分, 感情, 上, 加上, 一个, 期限, 的话, 我, 希望, 是, 有, 万年, ！
#
# ###搜索引擎模式###
# 我爱你, 。, 如果, 要, 在, 个, 分, 感情, 上, 加上, 一个, 期限, 的话, 我, 希望, 是, 有, 万年, ！
#
# ###词性标注###
# 我爱你 l
# 。 x
# 如果 c
# 要 v
# 在 p
# 个分 n
# 感情 n
# 上 f
# 加上 v
# 一个 m
# 期限 n
# 的话 u
# 我 r
# 希望 v
# 是 v
# 有 v
# 万年 m
# ！ x

# %%
#@title 영어 형태소 분석 - NLTK
영어문장 = 'Great power always comes with great responsibility.'  #@param {type: "string"}

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

영어토큰화 = nltk.tokenize.word_tokenize(영어문장)


from IPython.display import clear_output
clear_output()
# encoding=utf-8

print("  ")
print(영어토큰화)

print("  ")
print(nltk.pos_tag(영어토큰화))
# Out:
#
# ['Great', 'power', 'always', 'comes', 'with', 'great', 'responsibility', '.']
#
# [('Great', 'NNP'), ('power', 'NN'), ('always', 'RB'), ('comes', 'VBZ'), ('with', 'IN'), ('great', 'JJ'), ('responsibility', 'NN'), ('.', '.')]
